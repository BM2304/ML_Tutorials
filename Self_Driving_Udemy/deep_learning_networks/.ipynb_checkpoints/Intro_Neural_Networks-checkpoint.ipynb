# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)

# %%
n_pts = 500
X, y = datasets.make_circles(n_samples=n_pts, random_state=123, noise=0.1, factor=0.2)
print(X[:10])
print(y[:10])
# Out:
# [[ 0.69855363 -0.37828961]
#  [-0.24842242  0.19107122]
#  [-0.17875904  0.25369748]
#  [-0.00730467 -0.25926669]
#  [-0.15984414  0.26691592]
#  [-0.80107169 -0.10865614]
#  [ 1.00816914  0.20730929]
#  [ 0.04397805 -0.28023607]
#  [-0.08348537 -0.13811437]
#  [-0.98892821 -0.0926102 ]]
# [0 1 1 1 1 0 0 1 1 0]

# %%
# pick all variables with y-->0
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %%
# Creating Model
model = Sequential()
# Hidden Layer with 4 Neurons
model.add(Dense(4, input_shape=(2,), activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(lr=0.01), 'binary_crossentropy', metrics=['accuracy'])

# %%
# Training Model
h = model.fit(x=X, y=y, verbose=1, batch_size=20, epochs=100, shuffle='true') # verbose -> print out while training
# Out:
# Epoch 1/100
# 500/500 [==============================] - 0s - loss: 0.6963 - acc: 0.5120
# Epoch 2/100
# 500/500 [==============================] - 0s - loss: 0.6938 - acc: 0.6180
# Epoch 3/100
# 500/500 [==============================] - 0s - loss: 0.6926 - acc: 0.5180
# Epoch 4/100
# 500/500 [==============================] - 0s - loss: 0.6916 - acc: 0.6780
# Epoch 5/100
# 500/500 [==============================] - 0s - loss: 0.6905 - acc: 0.6340
# Epoch 6/100
# 500/500 [==============================] - 0s - loss: 0.6890 - acc: 0.3640
# Epoch 7/100
# 500/500 [==============================] - 0s - loss: 0.6866 - acc: 0.6460
# Epoch 8/100
# 500/500 [==============================] - 0s - loss: 0.6839 - acc: 0.6700
# Epoch 9/100
# 500/500 [==============================] - 0s - loss: 0.6797 - acc: 0.7580
# Epoch 10/100
# 500/500 [==============================] - 0s - loss: 0.6735 - acc: 0.7960
# Epoch 11/100
# 500/500 [==============================] - 0s - loss: 0.6661 - acc: 0.8380
# Epoch 12/100
# 500/500 [==============================] - 0s - loss: 0.6550 - acc: 0.8580
# Epoch 13/100
# 500/500 [==============================] - 0s - loss: 0.6425 - acc: 0.8780
# Epoch 14/100
# 500/500 [==============================] - 0s - loss: 0.6273 - acc: 0.8920
# Epoch 15/100
# 500/500 [==============================] - 0s - loss: 0.6082 - acc: 0.8800
# Epoch 16/100
# 500/500 [==============================] - 0s - loss: 0.5888 - acc: 0.8700
# Epoch 17/100
# 500/500 [==============================] - 0s - loss: 0.5682 - acc: 0.8860
# Epoch 18/100
# 500/500 [==============================] - 0s - loss: 0.5448 - acc: 0.8560
# Epoch 19/100
# 500/500 [==============================] - 0s - loss: 0.5227 - acc: 0.8860
# Epoch 20/100
# 500/500 [==============================] - 0s - loss: 0.4983 - acc: 0.8880
# Epoch 21/100
# 500/500 [==============================] - 0s - loss: 0.4758 - acc: 0.8880
# Epoch 22/100
# 500/500 [==============================] - 0s - loss: 0.4530 - acc: 0.8920
# Epoch 23/100
# 500/500 [==============================] - 0s - loss: 0.4307 - acc: 0.8920
# Epoch 24/100
# 500/500 [==============================] - 0s - loss: 0.4098 - acc: 0.9040
# Epoch 25/100
# 500/500 [==============================] - 0s - loss: 0.3904 - acc: 0.9000
# Epoch 26/100
# 500/500 [==============================] - 0s - loss: 0.3706 - acc: 0.9140
# Epoch 27/100
# 500/500 [==============================] - 0s - loss: 0.3521 - acc: 0.9100
# Epoch 28/100
# 500/500 [==============================] - 0s - loss: 0.3349 - acc: 0.9160
# Epoch 29/100
# 500/500 [==============================] - 0s - loss: 0.3180 - acc: 0.9180
# Epoch 30/100
# 500/500 [==============================] - 0s - loss: 0.3025 - acc: 0.9220
# Epoch 31/100
# 500/500 [==============================] - 0s - loss: 0.2875 - acc: 0.9240
# Epoch 32/100
# 500/500 [==============================] - 0s - loss: 0.2738 - acc: 0.9320
# Epoch 33/100
# 500/500 [==============================] - 0s - loss: 0.2609 - acc: 0.9420
# Epoch 34/100
# 500/500 [==============================] - 0s - loss: 0.2489 - acc: 0.9440
# Epoch 35/100
# 500/500 [==============================] - 0s - loss: 0.2372 - acc: 0.9640
# Epoch 36/100
# 500/500 [==============================] - 0s - loss: 0.2261 - acc: 0.9800
# Epoch 37/100
# 500/500 [==============================] - 0s - loss: 0.2162 - acc: 0.9860
# Epoch 38/100
# 500/500 [==============================] - 0s - loss: 0.2062 - acc: 0.9860
# Epoch 39/100
# 500/500 [==============================] - 0s - loss: 0.1969 - acc: 0.9900
# Epoch 40/100
# 500/500 [==============================] - 0s - loss: 0.1878 - acc: 0.9940
# Epoch 41/100
# 500/500 [==============================] - 0s - loss: 0.1794 - acc: 0.9940
# Epoch 42/100
# 500/500 [==============================] - 0s - loss: 0.1714 - acc: 0.9940
# Epoch 43/100
# 500/500 [==============================] - 0s - loss: 0.1638 - acc: 0.9960
# Epoch 44/100
# 500/500 [==============================] - 0s - loss: 0.1563 - acc: 0.9960
# Epoch 45/100
# 500/500 [==============================] - 0s - loss: 0.1494 - acc: 0.9960
# Epoch 46/100
# 500/500 [==============================] - 0s - loss: 0.1422 - acc: 0.9960
# Epoch 47/100
# 500/500 [==============================] - 0s - loss: 0.1353 - acc: 0.9960
# Epoch 48/100
# 500/500 [==============================] - 0s - loss: 0.1284 - acc: 0.9960
# Epoch 49/100
# 500/500 [==============================] - 0s - loss: 0.1213 - acc: 0.9960
# Epoch 50/100
# 500/500 [==============================] - 0s - loss: 0.1148 - acc: 0.9960
# Epoch 51/100
# 500/500 [==============================] - 0s - loss: 0.1081 - acc: 0.9960
# Epoch 52/100
# 500/500 [==============================] - 0s - loss: 0.1021 - acc: 0.9960
# Epoch 53/100
# 500/500 [==============================] - 0s - loss: 0.0966 - acc: 0.9960
# Epoch 54/100
# 500/500 [==============================] - 0s - loss: 0.0913 - acc: 0.9960
# Epoch 55/100
# 500/500 [==============================] - 0s - loss: 0.0866 - acc: 0.9960
# Epoch 56/100
# 500/500 [==============================] - 0s - loss: 0.0823 - acc: 0.9960
# Epoch 57/100
# 500/500 [==============================] - 0s - loss: 0.0783 - acc: 0.9980
# Epoch 58/100
# 500/500 [==============================] - 0s - loss: 0.0747 - acc: 0.9980
# Epoch 59/100
# 500/500 [==============================] - 0s - loss: 0.0713 - acc: 0.9980
# Epoch 60/100
# 500/500 [==============================] - 0s - loss: 0.0683 - acc: 0.9980
# Epoch 61/100
# 500/500 [==============================] - 0s - loss: 0.0653 - acc: 0.9980
# Epoch 62/100
# 500/500 [==============================] - 0s - loss: 0.0626 - acc: 0.9980
# Epoch 63/100
# 500/500 [==============================] - 0s - loss: 0.0602 - acc: 0.9980
# Epoch 64/100
# 500/500 [==============================] - 0s - loss: 0.0578 - acc: 0.9980
# Epoch 65/100
# 500/500 [==============================] - 0s - loss: 0.0557 - acc: 0.9980
# Epoch 66/100
# 500/500 [==============================] - 0s - loss: 0.0537 - acc: 0.9980
# Epoch 67/100
# 500/500 [==============================] - 0s - loss: 0.0518 - acc: 0.9980
# Epoch 68/100
# 500/500 [==============================] - 0s - loss: 0.0499 - acc: 0.9980
# Epoch 69/100
# 500/500 [==============================] - 0s - loss: 0.0483 - acc: 0.9980
# Epoch 70/100
# 500/500 [==============================] - 0s - loss: 0.0467 - acc: 0.9980
# Epoch 71/100
# 500/500 [==============================] - 0s - loss: 0.0452 - acc: 0.9980
# Epoch 72/100
# 500/500 [==============================] - 0s - loss: 0.0438 - acc: 0.9980
# Epoch 73/100
# 500/500 [==============================] - 0s - loss: 0.0425 - acc: 0.9980
# Epoch 74/100
# 500/500 [==============================] - 0s - loss: 0.0411 - acc: 0.9980
# Epoch 75/100
# 500/500 [==============================] - 0s - loss: 0.0399 - acc: 0.9980
# Epoch 76/100
# 500/500 [==============================] - 0s - loss: 0.0388 - acc: 0.9980
# Epoch 77/100
# 500/500 [==============================] - 0s - loss: 0.0377 - acc: 0.9980
# Epoch 78/100
# 500/500 [==============================] - 0s - loss: 0.0366 - acc: 0.9980
# Epoch 79/100
# 500/500 [==============================] - 0s - loss: 0.0356 - acc: 0.9980
# Epoch 80/100
# 500/500 [==============================] - 0s - loss: 0.0347 - acc: 0.9980
# Epoch 81/100
# 500/500 [==============================] - 0s - loss: 0.0339 - acc: 0.9980
# Epoch 82/100
# 500/500 [==============================] - 0s - loss: 0.0329 - acc: 0.9980
# Epoch 83/100
# 500/500 [==============================] - 0s - loss: 0.0320 - acc: 0.9980
# Epoch 84/100
# 500/500 [==============================] - 0s - loss: 0.0312 - acc: 0.9980
# Epoch 85/100
# 500/500 [==============================] - 0s - loss: 0.0305 - acc: 0.9980
# Epoch 86/100
# 500/500 [==============================] - 0s - loss: 0.0297 - acc: 1.0000
# Epoch 87/100
# 500/500 [==============================] - 0s - loss: 0.0290 - acc: 1.0000
# Epoch 88/100
# 500/500 [==============================] - 0s - loss: 0.0283 - acc: 1.0000
# Epoch 89/100
# 500/500 [==============================] - 0s - loss: 0.0277 - acc: 1.0000
# Epoch 90/100
# 500/500 [==============================] - 0s - loss: 0.0270 - acc: 1.0000
# Epoch 91/100
# 500/500 [==============================] - 0s - loss: 0.0264 - acc: 1.0000
# Epoch 92/100
# 500/500 [==============================] - 0s - loss: 0.0259 - acc: 1.0000
# Epoch 93/100
# 500/500 [==============================] - 0s - loss: 0.0253 - acc: 1.0000
# Epoch 94/100
# 500/500 [==============================] - 0s - loss: 0.0247 - acc: 1.0000
# Epoch 95/100
# 500/500 [==============================] - 0s - loss: 0.0242 - acc: 1.0000
# Epoch 96/100
# 500/500 [==============================] - 0s - loss: 0.0237 - acc: 1.0000
# Epoch 97/100
# 500/500 [==============================] - 0s - loss: 0.0232 - acc: 1.0000
# Epoch 98/100
# 500/500 [==============================] - 0s - loss: 0.0227 - acc: 1.0000
# Epoch 99/100
# 500/500 [==============================] - 0s - loss: 0.0222 - acc: 1.0000
# Epoch 100/100
# 500/500 [==============================] - 0s - loss: 0.0217 - acc: 1.0000

# %%
# Printing Accuracy
plt.plot(h.history['acc'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.title('accuracy')
plt.show()

# %%
plt.plot(h.history['loss'])
plt.xlabel('epoch')
plt.legend(['loss'])
plt.title('loss')
plt.show()

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:,0]) - 0.25, max(X[:,0]) + 0.25)
    y_span = np.linspace(min(X[:,1]) - 0.25, max(X[:,1]) + 0.25)
    xx, yy = np.meshgrid(x_span, y_span)
    grid = np.c_[xx.ravel(), yy.ravel()]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plot_decision_boundary(X, y, model)
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# Predict new point
x = 0.1
y = 0.7
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker='o', markersize=10, color='red')
plt.show()
print('Prediction is: ', prediction)
# Out:
# Prediction is:  [[0.03363342]]
